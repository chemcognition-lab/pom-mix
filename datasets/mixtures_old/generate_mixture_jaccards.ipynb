# %%
import pandas as pd
from collections import defaultdict
from rdkit.Chem import MolFromSmiles, MolToSmiles

# %%
mix_df = pd.read_csv("mixture_smi_definitions_clean.csv")
gslf_df = pd.read_csv("../gs-lf/gs-lf_combined.csv")

# %%
def transform_dataframe(df):
    # Create a dictionary to store unique SMILES and their sources
    smiles_dict = defaultdict(list)
    
    # Iterate through the DataFrame
    for _, row in df.iterrows():
        dataset = row['Dataset']
        mixture_label = row['Mixture Label']
        source = f"{dataset}_{mixture_label}"
        
        # Check all smi_n columns
        for col in df.columns:
            if col.startswith('smi_'):
                smiles = row[col]
                if pd.notna(smiles):  # Check if the SMILES is not NaN
                    smiles_dict[smiles].append(source)
    
    # Create the new DataFrame
    new_df = pd.DataFrame({
        'SMILES': list(smiles_dict.keys()),
        'Sources': [','.join(sources) for sources in smiles_dict.values()]
    })
    
    return new_df

# %%
mix_smi_df = transform_dataframe(mix_df)
mix_smi_df['canonical_smiles'] = mix_smi_df.apply(lambda row: MolToSmiles(MolFromSmiles(row['SMILES'])), axis=1)
gslf_df['canonical_smiles'] = gslf_df.apply(lambda row: MolToSmiles(MolFromSmiles(row['IsomericSMILES'])), axis=1)

merged_df = pd.merge(mix_smi_df, gslf_df, on='canonical_smiles', how='left')

# %%
merged_df[merged_df['descriptors'].isna()]
# Out:
#                                       SMILES  \
# 11    CC(=O)O[C@@H]1C[C@@H]2CC[C@]1(C2(C)C)C
# 13                                 CCCCNCCCC
# 28                    CC(=CCC[C@](C)(C=C)O)C
# 36                  CC1=CC(=C(C=C1Cl)C(C)C)O
# 42                               CCC/C=C/C=O
# 44                            C#CC1=CC=CC=C1
# 50                         CCCCC/C=C/C=C/C=O
# 52   C/C/1=C\CCC(=C)[C@H]2CC([C@@H]2CC1)(C)C
# 53               CC/C=C/1\C2=CC=CC=C2C(=O)O1
# 75         C[C@@H]1CC[C@H]([C@@H](C1)O)C(C)C
# 85                         C(C(=O)O)SCC(=O)O
# 92                              CC[C@@H](C)O
# 98                      CC(=CCC/C(=C/CO)/C)C
# 99                     CC(=CCC/C(=C/C=O)/C)C
# 104                               CC/C=C/CCO
# 110                    C[C@@H](CCC=C(C)C)CCO
# 113                               CCC/C=C/CO
# 119                C/C=C/C1=CC(=C(C=C1)OC)OC
# 121                    C1=CC=C(C=C1)/C=C/C=O
# 130                        CCCCCC/C=C/C(=O)C
# 140            CC(C)CCOC(=O)/C=C/C1=CC=CC=C1
# 141                     CC/C=C\CCOC(=O)C(C)O
# 146             CC(C)COC(=O)/C=C/C1=CC=CC=C1
# 152                        CC/C=C\CCOC(=O)CC
# 155                       CCOC(=O)/C=C/C=C/C
# 159              CC/C=C\CCOC(=O)CC1=CC=CC=C1
# 163                      C(=C/C(=O)O)\C(=O)O
# 164                  CC1=CC[C@@H](CC1)C(=C)C
# 171                 CC1=CC[C@H](CC1)C(C)(C)O
# 192              CC/C=C\1/C2=CC=CC=C2C(=O)O1
# 195             CC1([C@H]2CCC(=C)[C@@H]1C2)C
#
#                                                Sources  \
# 11   Snitz 1_2,Snitz 1_4,Snitz 1_5,Snitz 1_6,Snitz ...
# 13   Snitz 1_2,Snitz 1_4,Snitz 1_5,Snitz 1_6,Snitz ...
# 28   Snitz 1_4,Snitz 1_5,Snitz 1_6,Snitz 1_7,Snitz ...
# 36   Snitz 1_5,Snitz 1_6,Snitz 1_17,Snitz 1_18,Snit...
# 42   Snitz 1_5,Snitz 1_6,Snitz 1_21,Snitz 1_23,Snit...
# 44   Snitz 1_5,Snitz 1_6,Snitz 1_13,Snitz 1_21,Snit...
# 50   Snitz 1_8,Snitz 1_9,Snitz 1_10,Snitz 1_17,Snit...
# 52   Snitz 1_9,Snitz 1_10,Snitz 1_22,Snitz 1_23,Sni...
# 53   Snitz 1_9,Snitz 1_10,Snitz 1_21,Snitz 1_23,Sni...
# 75   Snitz 1_14,Snitz 1_16,Snitz 1_17,Snitz 1_18,Sn...
# 85                                          Snitz 1_41
# 92   Ravia_1,Ravia_4,Ravia_5,Ravia_8,Ravia_9,Ravia_...
# 98   Ravia_1,Ravia_2,Ravia_4,Ravia_9,Ravia_10,Ravia...
# 99   Ravia_1,Ravia_4,Ravia_6,Ravia_7,Ravia_8,Ravia_...
# 104  Ravia_2,Ravia_5,Ravia_6,Ravia_7,Ravia_8,Ravia_...
# 110  Ravia_4,Ravia_6,Ravia_10,Ravia_12,Ravia_13,Rav...
# 113  Ravia_4,Ravia_5,Ravia_6,Ravia_7,Ravia_8,Ravia_...
# 119  Ravia_7,Ravia_11,Ravia_14,Ravia_16,Ravia_17,Ra...
# 121  Ravia_127,Ravia_132,Bushdid_2,Bushdid_9,Bushdi...
# 130                                Ravia_137,Ravia_143
# 140                      Ravia_139,Ravia_143,Ravia_144
# 141                      Ravia_139,Ravia_145,Ravia_147
# 146                                Ravia_141,Ravia_146
# 152                                Ravia_143,Ravia_148
# 155                                Ravia_144,Ravia_146
# 159                                Ravia_145,Ravia_147
# 163                                Ravia_146,Ravia_147
# 164  Bushdid_1,Bushdid_20,Bushdid_26,Bushdid_27,Bus...
# 171  Bushdid_1,Bushdid_28,Bushdid_36,Bushdid_37,Bus...
# 192  Bushdid_11,Bushdid_12,Bushdid_17,Bushdid_18,Bu...
# 195  Bushdid_11,Bushdid_12,Bushdid_23,Bushdid_24,Bu...
#
#                             canonical_smiles IsomericSMILES descriptors  \
# 11   CC(=O)O[C@@H]1C[C@@H]2CC[C@@]1(C)C2(C)C            NaN         NaN
# 13                                 CCCCNCCCC            NaN         NaN
# 28                    C=C[C@](C)(O)CCC=C(C)C            NaN         NaN
# 36                     Cc1cc(O)c(C(C)C)cc1Cl            NaN         NaN
# 42                               CCC/C=C/C=O            NaN         NaN
# 44                               C#Cc1ccccc1            NaN         NaN
# 50                         CCCCC/C=C/C=C/C=O            NaN         NaN
# 52     C=C1CC/C=C(\C)CC[C@@H]2[C@@H]1CC2(C)C            NaN         NaN
# 53                   CC/C=C1/OC(=O)c2ccccc21            NaN         NaN
# 75           CC(C)[C@@H]1CC[C@@H](C)C[C@H]1O            NaN         NaN
# 85                           O=C(O)CSCC(=O)O            NaN         NaN
# 92                              CC[C@@H](C)O            NaN         NaN
# 98                       CC(C)=CCC/C(C)=C/CO            NaN         NaN
# 99                      CC(C)=CCC/C(C)=C/C=O            NaN         NaN
# 104                               CC/C=C/CCO            NaN         NaN
# 110                     CC(C)=CCC[C@H](C)CCO            NaN         NaN
# 113                               CCC/C=C/CO            NaN         NaN
# 119                   C/C=C/c1ccc(OC)c(OC)c1            NaN         NaN
# 121                         O=C/C=C/c1ccccc1            NaN         NaN
# 130                        CCCCCC/C=C/C(C)=O            NaN         NaN
# 140               CC(C)CCOC(=O)/C=C/c1ccccc1            NaN         NaN
# 141                     CC/C=C\CCOC(=O)C(C)O            NaN         NaN
# 146                CC(C)COC(=O)/C=C/c1ccccc1            NaN         NaN
# 152                        CC/C=C\CCOC(=O)CC            NaN         NaN
# 155                       C/C=C/C=C/C(=O)OCC            NaN         NaN
# 159                 CC/C=C\CCOC(=O)Cc1ccccc1            NaN         NaN
# 163                        O=C(O)/C=C/C(=O)O            NaN         NaN
# 164                   C=C(C)[C@H]1CC=C(C)CC1            NaN         NaN
# 171                CC1=CC[C@@H](C(C)(C)O)CC1            NaN         NaN
# 192                  CC/C=C1\OC(=O)c2ccccc21            NaN         NaN
# 195               C=C1CC[C@H]2C[C@@H]1C2(C)C            NaN         NaN
#
#      alcoholic  aldehydic  alliaceous  almond  amber  ...  tropical  vanilla  \
# 11         NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 13         NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 28         NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 36         NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 42         NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 44         NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 50         NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 52         NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 53         NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 75         NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 85         NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 92         NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 98         NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 99         NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 104        NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 110        NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 113        NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 119        NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 121        NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 130        NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 140        NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 141        NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 146        NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 152        NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 155        NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 159        NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 163        NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 164        NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 171        NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 192        NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
# 195        NaN        NaN         NaN     NaN    NaN  ...       NaN      NaN
#
#      vegetable  vetiver  violet  warm  waxy  weedy  winey  woody
# 11         NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 13         NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 28         NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 36         NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 42         NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 44         NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 50         NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 52         NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 53         NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 75         NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 85         NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 92         NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 98         NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 99         NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 104        NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 110        NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 113        NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 119        NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 121        NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 130        NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 140        NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 141        NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 146        NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 152        NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 155        NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 159        NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 163        NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 164        NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 171        NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 192        NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
# 195        NaN      NaN     NaN   NaN   NaN    NaN    NaN    NaN
#
# [31 rows x 143 columns]

# %%
mix_smi_df
# Out:
#                             SMILES  \
# 0    CCOC(=O)C1C(O1)(C)C2=CC=CC=C2
# 1                        CCCC(=O)O
# 2                  CC1=CC=C(C=C1)O
# 3        CC1=CC=C(C=C1)OC(=O)C(C)C
# 4                 CC1=CC=C(C=C1)OC
# ..                             ...
# 198                           CC=O
# 199           CC(=O)OCCC1=CC=CC=C1
# 200             CC1=CCC(C=C1)C(C)C
# 201                        CCC(C)S
# 202                   CCCCC(=O)OCC
#
#                                                Sources  \
# 0    Snitz 1_1,Snitz 1_9,Snitz 1_10,Snitz 1_21,Snit...
# 1    Snitz 1_1,Snitz 1_9,Snitz 1_10,Snitz 1_21,Snit...
# 2    Snitz 1_1,Snitz 1_10,Snitz 1_18,Snitz 1_28,Sni...
# 3    Snitz 1_1,Snitz 1_9,Snitz 1_10,Snitz 1_21,Snit...
# 4    Snitz 1_1,Snitz 1_10,Snitz 1_12,Snitz 1_18,Sni...
# ..                                                 ...
# 198  Bushdid_15,Bushdid_38,Bushdid_39,Bushdid_40,Bu...
# 199  Bushdid_23,Bushdid_36,Bushdid_54,Bushdid_61,Bu...
# 200  Bushdid_25,Bushdid_28,Bushdid_47,Bushdid_48,Bu...
# 201  Bushdid_25,Bushdid_29,Bushdid_31,Bushdid_32,Bu...
# 202  Bushdid_33,Bushdid_34,Bushdid_36,Bushdid_39,Bu...
#
#              canonical_smiles
# 0    CCOC(=O)C1OC1(C)c1ccccc1
# 1                   CCCC(=O)O
# 2                Cc1ccc(O)cc1
# 3      Cc1ccc(OC(=O)C(C)C)cc1
# 4               COc1ccc(C)cc1
# ..                        ...
# 198                      CC=O
# 199         CC(=O)OCCc1ccccc1
# 200        CC1=CCC(C(C)C)C=C1
# 201                   CCC(C)S
# 202              CCCCC(=O)OCC
#
# [203 rows x 3 columns]
